# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/CS6101
# Out:
# Mounted at /content/gdrive

# %%
# !pip3 install virtualenv
# !virtualenv theanoEnv
# Out:
# ...
#      |████████████████████████████████| 7.2MB 5.2MB/s
# ...
#      |████████████████████████████████| 337kB 51.0MB/s
# ...
# created virtual environment CPython3.6.9.final.0-64 in 6491ms
#   creator CPython3Posix(dest=/content/gdrive/My Drive/CS6101/theanoEnv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.0.1, setuptools==52.0.0, wheel==0.36.2
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator

# %%
# !source theanoEnv/bin/activate; pip3 install theano==0.8.0 && pip3 install keras==1.0.7 && pip3 install h5py && pip3 install numpy==1.11.0; python3 NeuMF.py --dataset ml-1m --epochs 20 --batch_size 256 --num_factors 8 --layers [64,32,16,8] --num_neg 4 --lr 0.001 --learner adam --verbose 1 --out 1 --mf_pretrain Pretrain/ml-1m_GMF_8_1501651698.h5 --mlp_pretrain Pretrain/ml-1m_MLP_[64,32,16,8]_1501652038.h5
# Out:
# ...
#      |████████████████████████████████| 135 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 640 kB 23.3 MB/s
# ...
#   Created wheel for keras: filename=Keras-1.0.7-py3-none-any.whl size=157415 sha256=cd8c6974af72e70c0c4dedb01bba080b56de7df3ed52ba589b055f8bfdad1dc0
#   Stored in directory: /root/.cache/pip/wheels/f6/cd/88/f9dc5fe46c9bfa7a217bc2e0f5f74f4b8bfa71b65b5da42f3c
# Successfully built keras
# ...
#      |████████████████████████████████| 4.0 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 4.5 MB/s
# ...
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#     Running setup.py install for numpy ... error
#   Rolling back uninstall of numpy
#   Moving to /content/gdrive/My Drive/CS6101/theanoEnv/bin/f2py
# ...

# %%
# !source theanoEnv/bin/activate; pip3 install theano==0.8.0 && pip3 install keras==1.0.7 && pip3 install h5py && pip3 install numpy==1.11.0; python3 NeuMF.py --dataset ml-1m --epochs 20 --batch_size 256 --num_factors 16 --layers [64,32,16,8] --num_neg 4 --lr 0.001 --learner adam --verbose 1 --out 1 
# --mf_pretrain Pretrain/ml-1m_GMF_8_1501651698.h5 --mlp_pretrain Pretrain/ml-1m_MLP_[64,32,16,8]_1501652038.h5
# Out:
# ...
#   Using cached numpy-1.11.0.zip (4.7 MB)
# ...
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#     Running setup.py install for numpy ... error
#   Rolling back uninstall of numpy
#   Moving to /content/gdrive/My Drive/CS6101/theanoEnv/bin/f2py
#    from /tmp/pip-uninstall-1f7atlm7/f2py
#   Moving to /content/gdrive/My Drive/CS6101/theanoEnv/bin/f2py3
#    from /tmp/pip-uninstall-1f7atlm7/f2py3
#   Moving to /content/gdrive/My Drive/CS6101/theanoEnv/bin/f2py3.6
#    from /tmp/pip-uninstall-1f7atlm7/f2py3.6
#   Moving to /content/gdrive/My Drive/CS6101/theanoEnv/lib/python3.6/site-packages/numpy-1.19.5.dist-info/
#    from /content/gdrive/My Drive/CS6101/theanoEnv/lib/python3.6/site-packages/~umpy-1.19.5.dist-info
# ...
